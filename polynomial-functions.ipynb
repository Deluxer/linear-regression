# %% [markdown]
# ## Polynomial Funcions

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# f(x) = x²

# %%
def f(x):
    return x**2

quantity = 100

x = np.linspace(-10, 10, num=quantity)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# P(x) = 2X⁷ - X⁴ + 3X⁴ + 4

# %%
def f(x):
    return 2*x**8 - x**4 + x*x**4 + 4

quantity = 100

x = np.linspace(-10, 10, num=quantity)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()
